# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
key='S5FgzVMaI4VnSdDKqpL5KZxsUmhhyDuYp5uEtbgdkcjiNs15Aw4199t39wANmq%2BTUjhIm999jORaRGsMwuUDrQ%3D%3D'
numRows=10
staD=str(20200410)
endD=str(20210831)
numRows=30

# %%
url1='http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson?serviceKey='+ key
url2='&pageNo=1&numOfRows='+str(numRows)
url3='&startCreateDt='+staD+'&endCreateDt='+endD
url=url1+url2+url3

# %%
xml=requests.get(url)
soup=bs(xml.text,'html.parser')
#soup

# %%
data=soup.find_all('item')
con_lst=[]

for item in data:
    DEF_CNT = item.find('defcnt').text # 확진자수'
    Deat_CNT = item.find('deathcnt').text # 사망자수
    GUBUN = item.find('gubun').text # 지역'
    INC_DEC = item.find('incdec').text #전일대비 증감'
    STD_DAY = item.find('stdday').text # 기준일'
    ISOL_ING_CNT = item.find('isolingcnt').text#격리자수'
    OVER_FLOW_CNT = item.find('overflowcnt').text #해외유입'
    LOCAL_OCC_CNT = item.find('localocccnt').text #지역감염'
    con_lst.append({'stdday':STD_DAY,'ji':GUBUN,'isolingcnt':ISOL_ING_CNT,
                    'defcnt':DEF_CNT,'incdec':INC_DEC,'deathcnt':Deat_CNT,
                    'local':LOCAL_OCC_CNT,'overflow':OVER_FLOW_CNT})

# %%
df = pd.DataFrame(con_lst)
df.head()
# Out:
#               stdday  ji isolingcnt defcnt incdec deathcnt local overflow
# 0  2021년 08월 31일 00시  검역        511   5836     13       13     0       13
# 1  2021년 08월 31일 00시  제주        270   2602      9        2     8        1
# 2  2021년 08월 31일 00시  경남        858   9980     56       31    56        0
# 3  2021년 08월 31일 00시  경북        618   7100     27       88    27        0
# 4  2021년 08월 31일 00시  전남        206   2600     14       19    13        1

# %%
df.isna().sum()
# Out:
# stdday        0
# ji            0
# isolingcnt    0
# defcnt        0
# incdec        0
# deathcnt      0
# local         0
# overflow      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   stdday      516 non-null    object
#  1   ji          516 non-null    object
#  2   isolingcnt  516 non-null    object
#  3   defcnt      516 non-null    object
#  4   incdec      516 non-null    object
#  5   deathcnt    516 non-null    object
#  6   local       516 non-null    object
#  7   overflow    516 non-null    object
# dtypes: object(8)
# memory usage: 32.4+ KB

# %%
# object .astype(int)
for col in df.columns[2:]:
    df[col] = df[col].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   stdday      516 non-null    object
#  1   ji          516 non-null    object
#  2   isolingcnt  516 non-null    int32
#  3   defcnt      516 non-null    int32
#  4   incdec      516 non-null    int32
#  5   deathcnt    516 non-null    int32
#  6   local       516 non-null    int32
#  7   overflow    516 non-null    int32
# dtypes: int32(6), object(2)
# memory usage: 20.3+ KB

# %%
df.describe()
# defcnt max 가 이상하다
# Out:
#          isolingcnt         defcnt       incdec     deathcnt       local  \
# count    516.000000     516.000000   516.000000   516.000000   516.00000
# mean    2626.494186   22719.133721   173.676357   216.153101   168.50000
# std     5870.341145   50167.372319   382.427085   475.594796   372.40069
# min       70.000000     763.000000     1.000000     1.000000     0.00000
# 25%      332.000000    3621.250000    25.000000    24.000000    23.00000
# 50%      602.000000    5560.500000    46.500000    57.000000    46.00000
# 75%     1168.500000   10628.000000    90.000000   128.000000    89.00000
# max    28214.000000  251415.000000  2221.000000  2285.000000  2144.00000
#
#          overflow
# count  516.000000
# mean     5.186047
# std     11.778550
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      3.000000
# max     77.000000

# %%
df[df.defcnt >= 100000]
#합계떄문에 그렇다
# Out:
#                 stdday  ji  isolingcnt  defcnt  incdec  deathcnt  local  \
# 18   2021년 08월 31일 00시  합계       27429  251415    1370      2285   1331
# 37   2021년 08월 30일 00시  합계       27403  250045    1485      2284   1424
# 56   2021년 08월 29일 00시  합계       27555  248560    1619      2279   1576
# 75   2021년 08월 28일 00시  합계       27678  246943    1791      2276   1736
# 94   2021년 08월 27일 00시  합계       28214  245152    1838      2265   1808
# 113  2021년 08월 26일 00시  합계       28186  243314    1882      2257   1829
# 132  2021년 08월 25일 00시  합계       28019  241433    2154      2237   2113
# 151  2021년 08월 24일 00시  합계       27859  239280    1506      2228   1468
# 170  2021년 08월 23일 00시  합계       27949  237772    1416      2222   1369
# 189  2021년 08월 22일 00시  합계       27864  236355    1626      2215   1588
# 208  2021년 08월 21일 00시  합계       28009  234729    1876      2202   1812
# 227  2021년 08월 20일 00시  합계       27880  232852    2050      2197   2000
# 246  2021년 08월 19일 00시  합계       27376  230802    2152      2191   2114
# 265  2021년 08월 18일 00시  합계       26890  228650    1803      2178   1766
# 284  2021년 08월 17일 00시  합계       27451  226848    1372      2173   1322
# 303  2021년 08월 16일 00시  합계       27111  225476    1555      2167   1492
# 322  2021년 08월 15일 00시  합계       26662  223921    1816      2156   1748
# 341  2021년 08월 14일 00시  합계       26179  222105    1928      2148   1858
# 360  2021년 08월 13일 00시  합계       25786  220177    1989      2144   1913
# 379  2021년 08월 12일 00시  합계       25516  218189    1987      2138   1947
# 398  2021년 08월 11일 00시  합계       24561  216202    2221      2135   2144
# 417  2021년 08월 10일 00시  합계       24324  213981    1536      2134   1474
# 436  2021년 08월 09일 00시  합계       24077  212444    1490      2125   1455
# 455  2021년 08월 08일 00시  합계       23829  210953    1728      2121   1669
#
#      overflow
# 18         39
# 37         61
# 56         43
# 75         55
# 94         30
# 113        53
# 132        41
# 151        38
# 170        47
# 189        38
# 208        65
# 227        50
# 246        38
# 265        37
# 284        50
# 303        63
# 322        68
# 341        70
# 360        76
# 379        40
# 398        77
# 417        63
# 436        36
# 455        59

# %%
df['defcnt'].groupby(df['ji']).sum()
#검역 , 합계 지워야한다
# Out:
# ji
# 강원     126546
# 검역     157110
# 경기    1682105
# 경남     249346
# 경북     178238
# 광주     104962
# 대구     357147
# 대전     142351
# 부산     275498
# 서울    1965322
# 세종      23212
# 울산     104332
# 인천     296572
# 전남      65681
# 전북      89329
# 제주      61652
# 충남     169354
# 충북     116718
# 합계    5557598
# Name: defcnt, dtype: int32

# %% [markdown]
# ## 전처리
# - 합계와 검역자료 제거
# - 날짜 데이터를 형식을 날짜 형식으로 변경 년, 월, 일 단위로 쪼갬

# %%
newDf = df[(df['ji']!= '검역') & (df['ji'] != '합계')]
# 방법 2 newDf = df 를 하고 조건에 맞는 자료만 drop(행단위로 axis=0)
# 방버 3 newDf = df 를 하고 조건에 맞는 자료만 nan 으로 변경한뒤 dropna로 제거

# %%
newDf['defcnt'].groupby(df['ji']).sum()
# Out:
# ji
# 강원     126546
# 경기    1682105
# 경남     249346
# 경북     178238
# 광주     104962
# 대구     357147
# 대전     142351
# 부산     275498
# 서울    1965322
# 세종      23212
# 울산     104332
# 인천     296572
# 전남      65681
# 전북      89329
# 제주      61652
# 충남     169354
# 충북     116718
# Name: defcnt, dtype: int32

# %%
newDf.corr() #상관도
# Out:
#             isolingcnt    defcnt    incdec  deathcnt     local  overflow
# isolingcnt    1.000000  0.993543  0.969242  0.942039  0.969495  0.720412
# defcnt        0.993543  1.000000  0.968791  0.962850  0.968815  0.731520
# incdec        0.969242  0.968791  1.000000  0.942731  0.999914  0.760173
# deathcnt      0.942039  0.962850  0.942731  1.000000  0.941928  0.752914
# local         0.969495  0.968815  0.999914  0.941928  1.000000  0.751582
# overflow      0.720412  0.731520  0.760173  0.752914  0.751582  1.000000

# %%
import seaborn as sns
sns.heatmap(newDf.corr(), annot=True) #annot 은 숫자
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(newDf.corr(), annot=True)

# %%
## 날짜
## 날짜 형식은 년 - 월 - 일

newDf['Date'] = newDf.stdday.str.split('일').str[0] #str
newDf['Date'] = newDf.Date.str.replace('년','-')
newDf['Date'] = newDf.Date.str.replace('월','-')
newDf['Date'] = newDf.Date.str.replace(' ','')

## 다른방법
'''

'''
# Out:
# C:\Users\TH\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# '\n\n'

# %%
newDf.Date
#아직 object이다
# Out:
# 1      2021-08-31
# 2      2021-08-31
# 3      2021-08-31
# 4      2021-08-31
# 5      2021-08-31
#           ...
# 511    2021-08-04
# 512    2021-08-04
# 513    2021-08-04
# 514    2021-08-04
# 515    2021-08-04
# Name: Date, Length: 464, dtype: object

# %%
from datetime import datetime, timedelta

newDf.Date = pd.to_datetime(newDf.Date)

# %%
newDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 464 entries, 1 to 515
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   stdday      464 non-null    object
#  1   ji          464 non-null    object
#  2   isolingcnt  464 non-null    int32
#  3   defcnt      464 non-null    int32
#  4   incdec      464 non-null    int32
#  5   deathcnt    464 non-null    int32
#  6   local       464 non-null    int32
#  7   overflow    464 non-null    int32
#  8   Date        464 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int32(6), object(2)
# memory usage: 41.5+ KB

# %%
newDf['year'] = newDf.Date.dt.year
newDf['month'] = newDf.Date.dt.month
newDf['dayName'] = newDf.Date.dt.day_name()

# %%
newDf.head()
# Out:
#               stdday  ji  isolingcnt  defcnt  incdec  deathcnt  local  \
# 1  2021년 08월 31일 00시  제주         270    2602       9         2      8
# 2  2021년 08월 31일 00시  경남         858    9980      56        31     56
# 3  2021년 08월 31일 00시  경북         618    7100      27        88     27
# 4  2021년 08월 31일 00시  전남         206    2600      14        19     13
# 5  2021년 08월 31일 00시  전북         354    3588      26        60     26
#
#    overflow       Date  year  month  dayName
# 1         1 2021-08-31  2021      8  Tuesday
# 2         0 2021-08-31  2021      8  Tuesday
# 3         0 2021-08-31  2021      8  Tuesday
# 4         1 2021-08-31  2021      8  Tuesday
# 5         0 2021-08-31  2021      8  Tuesday

# %%
List = newDf.ji.unique()
import matplotlib.pyplot as plt

for i in List:
    print('------',i,'------')
    tmp = newDf[newDf.ji==i]
    #sns.boxplot(x='dayName', y='defcnt', data=tmp)
    sns.boxplot(x='month', y='defcnt', hue=tmp['dayName'], data=tmp)
    plt.show()
# Out:
# ------ 제주 ------
# ------ 경남 ------
# ------ 경북 ------
# ------ 전남 ------
# ------ 전북 ------
# ------ 충남 ------
# ------ 충북 ------
# ------ 강원 ------
# ------ 경기 ------
# ------ 세종 ------
# ------ 울산 ------
# ------ 대전 ------
# ------ 광주 ------
# ------ 인천 ------
# ------ 대구 ------
# ------ 부산 ------
# ------ 서울 ------
