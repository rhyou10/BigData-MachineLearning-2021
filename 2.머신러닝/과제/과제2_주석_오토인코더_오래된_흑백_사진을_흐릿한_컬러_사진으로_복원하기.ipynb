# %% [markdown]
# ### . 구글 drive와 colab 연동하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/data/딥러닝
# Out:
# /content/drive/MyDrive/data/딥러닝

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
from IPython.display import Image

warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 34

# %% [markdown]
# ## [1] 데이터셋의 이해
#
# - 구글검색 'pfcn 데이터셋'  을 검색하고 pfcn 자료에 대하여 정리하세요
#
# - 자료를 보았을 때 사람의 얼굴 사진에 대한 데이터와 사람을 제외한 배경을 검은색으로 사람은 하얀색으로 만들어 놓은 데이터셋.

# %% [markdown]
# ## [2] 자료 로딩 및 검수

# %% [markdown]
# ### 1-1. pfcn_small.npz 파일 읽기

# %%
data=np.load('pfcn_small.npz')
print(list(data))
train_images = data['train_images']   # X값이 될 이미지
test_images = data['test_images']     # y값 이미지
# Out:
# ['train_images', 'test_images', 'train_mattes', 'test_mattes']

# %%
np.shape(data['train_mattes'][0:1])
# Out:
# (1, 100, 75)

# %%
plt.imshow(data['train_mattes'][0:1].reshape(100,-1),cmap='gray')

# %%
# 주석작성 - print shape 에  대한 해석
# y_train 에 100*75모양의 컬러사진 1700 장
# y_test 에 100*75모양의 컬러사진 300 장

print('y train=>',np.shape(train_images))

print('y test=>',np.shape(test_images))
# Out:
# y train=> (1700, 100, 75, 3)
# y test=> (300, 100, 75, 3)

# %%
# 주석작성 - 아래 작업을 왜 하는지
# 스케일링 여부 확인

print('----------train data-----------')
print(train_images.min(), train_images.max())

print('----------test data-----------')
print(test_images.min(), test_images.max())
# Out:
# ----------train data-----------
# 0.0 1.0
# ----------test data-----------
# 0.0 1.0

# %%
# 주석작성 -  아래 코드의 기능에 대하여 설명

# 사진을 이어붙여서 본다
# trin image[:5]의 shape는  5 100 75 3 인데 traspose를 통해 인덱스를 바꾼뒤 reshape해 볼수 있다
# 즉 100 5 75 3 의경우 100 5*75 3 의 모양으로 이어붙였을때의 크기와 같이 나온다
# 3번째의 경우로 보면 사진이 가로가아닌 세로로 연결됨을 볼 수 있다
# 4번째의 경우 transpose 순서가 바뀌어 이상하게 나옴을 볼 수 있다

plt.imshow(np.hstack(train_images[:5]))
plt.show()
plt.imshow(train_images[:5].transpose((1,0,2,3)).reshape((100, -1, 3)))
plt.show()
plt.imshow(train_images[:5].reshape((100, 375, 3)))
plt.show()
plt.imshow(train_images[:5].transpose((2,1,0,3)).reshape((100, -1, 3)))
plt.show()

# %% [markdown]
# ## [3] x데이터 제작 및 모델링

# %%
# 주석작성 아래 코드에 대한 설명
# color를 rgb2gray를 통해 흑백으로 바꾸는 코드(train data 제작)
from skimage import color

train_gray_images = np.array([color.rgb2gray(img).reshape((100, 75, 1)) for img in train_images])
test_gray_images = np.array([color.rgb2gray(img).reshape((100, 75, 1)) for img in test_images])

print(train_gray_images.shape, test_gray_images.shape)
# Out:
# (1700, 100, 75, 1) (300, 100, 75, 1)

# %%
plt.imshow(train_gray_images[0].reshape(100,75),cmap='gray')

# %%
show_gray_img = train_gray_images.reshape(-1,100,75)

# %%
show_gray_img.shape
# Out:
# (1700, 100, 75)

# %%
# 작업- 아래의 출력물과 같이 train_gray_images도 위의 컬러 자료와 같이 출력 


plt.imshow(np.hstack(show_gray_img[:5]),cmap='gray')
plt.show()
plt.imshow(show_gray_img[:5].transpose((1,0,2)).reshape((100, -1)),cmap='gray')
plt.show()
plt.imshow(show_gray_img[:5].reshape((100, 375)),cmap='gray')
plt.show()
plt.imshow(show_gray_img[:5].transpose((2,1,0)).reshape((100, -1)),cmap='gray')
plt.show()

# %%
# 주석 작성- 아래 코드에 대하여 설명, summary 했을때 결과값의  Output Shape 의 숫자 계산하면 좋음
# 오토인코더형태를 사용?


from keras.layers import Dense, Input, Conv2D, Conv2DTranspose, Flatten, Reshape, MaxPool2D
from keras.models import Model
from keras.layers import BatchNormalization, Dropout, Activation, concatenate

def conv2d_block(x, channel):
    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x
    
def unet_color():
    inputs = Input((100, 75, 1))

    c1 = conv2d_block(inputs, 16)
    p1 = MaxPool2D(2)(c1)
    p1 = Dropout(0.1)(p1)

    c2 = conv2d_block(p1, 32)
    p2 = MaxPool2D(2)(c2)
    p2 = Dropout(0.1)(p2)

    c3 = conv2d_block(p2, 64)
    p3 = MaxPool2D(2)(c3)
    p3 = Dropout(0.1)(p3)

    c4 = conv2d_block(p3, 128)
    p4 = MaxPool2D(2)(c4)
    p4 = Dropout(0.1)(p4)

    c5 = conv2d_block(p4, 256)

    u6 = Conv2DTranspose(128, 2, 2, padding="valid", output_padding=(0,1))(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(0.1)(u6)
    c6 = conv2d_block(u6, 128)

    u7 = Conv2DTranspose(64, 2, 2, padding="valid", output_padding=(1,0))(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(0.1)(u7)
    c7 = conv2d_block(u7, 64)

    u8 = Conv2DTranspose(32, 2, 2, padding="valid", output_padding=(0,1))(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(0.1)(u8)
    c8 = conv2d_block(u8, 32)

    u9 = Conv2DTranspose(16, 2, 2, padding="valid", output_padding=(0,1))(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(0.1)(u9)
    c9 = conv2d_block(u9, 16)

    outputs = Conv2D(3, 1, activation="sigmoid")(c9)
    model = Model(inputs, outputs)
    return model

# %%
# 위자료와 param및 shape 갯수 맞는지 확인
model = unet_color()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 75, 1)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 75, 16)  160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 100, 75, 16)  64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 100, 75, 16)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 75, 16)  2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 75, 16)  64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 100, 75, 16)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 50, 37, 16)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 50, 37, 16)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 37, 32)   4640        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 37, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 50, 37, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 50, 37, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 37, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 50, 37, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 25, 18, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 25, 18, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 25, 18, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 25, 18, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 25, 18, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 25, 18, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 25, 18, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 25, 18, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 9, 64)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 12, 9, 64)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 12, 9, 128)   73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 12, 9, 128)   512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 12, 9, 128)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 12, 9, 128)   147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 12, 9, 128)   512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 12, 9, 128)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 4, 128)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 6, 4, 128)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 6, 4, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 6, 4, 256)    1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 6, 4, 256)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 6, 4, 256)    590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 6, 4, 256)    1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 6, 4, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 12, 9, 128)   131200      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12, 9, 256)   0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 12, 9, 256)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 9, 128)   295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 12, 9, 128)   512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 9, 128)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 12, 9, 128)   147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 12, 9, 128)   512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 9, 128)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 25, 18, 64)   32832       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 25, 18, 128)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 25, 18, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 18, 64)   73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 18, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 18, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 18, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 18, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 18, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 50, 37, 32)   8224        activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 50, 37, 64)   0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 50, 37, 64)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 50, 37, 32)   18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 37, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 50, 37, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 37, 32)   9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 37, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 50, 37, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 100, 75, 16)  2064        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 100, 75, 32)  0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 100, 75, 32)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 100, 75, 16)  4624        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 100, 75, 16)  64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 100, 75, 16)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 100, 75, 16)  2320        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 100, 75, 16)  64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 100, 75, 16)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 100, 75, 3)   51          activation_17[0][0]
# ==================================================================================================
# Total params: 1,946,739
# Trainable params: 1,943,795
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
# 주석작성 텐서플로우의 optimizer 의 종류와 특성 간단하게
# 1. 경사 하강법(Gradient Descent)   -> 기울기계산 
# 2. 확률적 경사 하강법(Stochastic Gradient Descent, SGD) -> 경사하강법데이터를 확률적으로 읽어 빠르게
# 3. Nesterov Accelerated Gradient (NAG)  --> 일단 움직이고, 스텝계산
# 4. Adam  --> RMSprop + momentum
# 5. AdaGrad  --> 조금씩 이동
# 6. RMSProp  --> 전에 상황보면서 이동
# 7. AdaMax  --> 
# 8. Nadam --> adam에 모멘텀대신 nag 붙임

model.compile(loss = "mse", optimizer="adam", metrics=["accuracy"])

# %%
# 주석작성: verbose 옵션값의 차이
# 0은 진행률 안보임, 1은 defalut 한줄정도, 2는 자세히


hist = model.fit(train_gray_images, train_images, validation_data=(test_gray_images, test_images), epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 20s 45ms/step - loss: 0.0251 - accuracy: 0.2851 - val_loss: 0.0651 - val_accuracy: 0.5487
# Epoch 2/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0111 - accuracy: 0.5179 - val_loss: 0.0626 - val_accuracy: 0.6892
# Epoch 3/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0093 - accuracy: 0.5872 - val_loss: 0.0533 - val_accuracy: 0.6890
# Epoch 4/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0086 - accuracy: 0.6031 - val_loss: 0.0469 - val_accuracy: 0.6224
# Epoch 5/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0081 - accuracy: 0.6217 - val_loss: 0.0402 - val_accuracy: 0.5707
# Epoch 6/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0079 - accuracy: 0.6270 - val_loss: 0.0325 - val_accuracy: 0.6122
# Epoch 7/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0075 - accuracy: 0.6277 - val_loss: 0.0247 - val_accuracy: 0.5753
# Epoch 8/50
# 54/54 [==============================] - 2s 32ms/step - loss: 0.0075 - accuracy: 0.6254 - val_loss: 0.0189 - val_accuracy: 0.6596
# Epoch 9/50
# 54/54 [==============================] - 2s 32ms/step - loss: 0.0073 - accuracy: 0.6388 - val_loss: 0.0140 - val_accuracy: 0.6721
# Epoch 10/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0073 - accuracy: 0.6399 - val_loss: 0.0085 - val_accuracy: 0.6823
# Epoch 11/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0072 - accuracy: 0.6393 - val_loss: 0.0081 - val_accuracy: 0.6641
# Epoch 12/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0072 - accuracy: 0.6438 - val_loss: 0.0067 - val_accuracy: 0.6525
# Epoch 13/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0070 - accuracy: 0.6500 - val_loss: 0.0064 - val_accuracy: 0.6671
# Epoch 14/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0069 - accuracy: 0.6438 - val_loss: 0.0068 - val_accuracy: 0.6440
# Epoch 15/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0069 - accuracy: 0.6510 - val_loss: 0.0063 - val_accuracy: 0.6580
# Epoch 16/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0070 - accuracy: 0.6425 - val_loss: 0.0066 - val_accuracy: 0.6650
# Epoch 17/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0068 - accuracy: 0.6490 - val_loss: 0.0065 - val_accuracy: 0.6641
# Epoch 18/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0067 - accuracy: 0.6489 - val_loss: 0.0066 - val_accuracy: 0.6436
# Epoch 19/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.
50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0042 - accuracy: 0.7069 - val_loss: 0.0063 - val_accuracy: 0.6538

# %%
plt.plot(hist.history['accuracy'], label='accuracy')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_accuracy'], label='val_accuracy')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend(loc='upper left')
plt.show()

# %%
# 주석작성:아래 코드 설명
# 테스트 흑백사진을 model에 넣어 예상함, 예상한 그림의 shape와 테스트 사진의 shape를 비교하여 흑백에서 컬러로 됬는지 확인
res = model.predict(test_gray_images[1:2])
print(test_gray_images[1:2].shape)
print(res.shape)
# Out:
# (1, 100, 75, 1)
# (1, 100, 75, 3)

# %%
# 주석작성: 코드설명
# 컬러로 바꾼 이미지 사이에 진짜 컬러사진
plt.imshow(np.concatenate([res[0], test_images[1], model.predict(test_gray_images[1:2])[0]], axis=1))

# %%
# 주석작성: 코드설명
# 컬러화 하기전 흑백사진
plt.imshow(test_gray_images[1][...,0], cmap="gray")

# %%
# 결과 확인
five = model.predict(test_gray_images[:5])
plt.imshow(np.concatenate([five, test_images[:5]], axis=1).transpose((1,0,2,3)).reshape((200, -1,3)))

# %% [markdown]
# ## [4] lab 칼라 모델링
# - lab 칼라에 대하여 조사하세요

# %%
# 주석작성: 코드 설명
# rgb2lab을통해 rgb 를 lab형태로 변경
train_lab_images = np.array([color.rgb2lab(img) for img in train_images])
test_lab_images = np.array([color.rgb2lab(img) for img in test_images])

# %%
train_lab_images.shape
# Out:
# (1700, 100, 75, 3)

# %%
train_images[0][0][4]
# Out:
# array([0.23921569, 0.34509804, 0.64705882])

# %%
# 주석작성: 코드설명
# lab 형태의 색깔에 최대치. 최소치
print(train_lab_images[..., 0].min(), train_lab_images[..., 0].max())
print(train_lab_images[..., 1].min(), train_lab_images[..., 1].max())
print(train_lab_images[..., 2].min(), train_lab_images[..., 2].max())
# Out:
# 0.0 100.0
# -78.53736435567544 86.20773183914271
# -91.97308466277427 93.80664030542576

# %%
plt.imshow(train_lab_images[...,0][0])

# %%
# 주석작성: 코드설명
# 첫번째 사진의 색 최대치 최소치
a = train_lab_images + [0, 128, 128]
print(a[...,0].min(), a[...,0].max())
print(a[...,1].min(), a[...,1].max())
print(a[...,2].min(), a[...,2].max())

b = a / [100., 255., 255.]
print(b[...,0].min(), b[...,0].max())
print(b[...,1].min(), b[...,1].max())
print(b[...,2].min(), b[...,2].max())
# Out:
# 0.0 100.0
# 49.462635644324564 214.2077318391427
# 36.02691533722573 221.80664030542576
# 0.0 1.0
# 0.19397112017382181 0.8400303209378145
# 0.141282020930297 0.8698299619820618

# %%
train_lab_images = (train_lab_images + [0, 128, 128]) / [100., 255., 255.]
test_lab_images = (test_lab_images + [0, 128, 128]) / [100., 255., 255.]

# %%
print(train_lab_images[...,0].min(), train_lab_images[...,0].max())
print(train_lab_images[...,1].min(), train_lab_images[...,1].max())
print(train_lab_images[...,2].min(), train_lab_images[...,2].max())
# Out:
# 0.0 1.0
# 0.19397112017382181 0.8400303209378145
# 0.141282020930297 0.8698299619820618

# %%
# 주석작성: 코드설명
# lab형태의 이미지를 흑백으로 출력한다
plt.imshow(test_lab_images[1][...,0], cmap="gray")
plt.show()

# %% [markdown]
# ### 과제내용은 위에서 끝임. 지금부터는 내용확인만 하세요.
# -  lab 칼라 첫번째 채널로 나머지 2채널을 예측하는 모델입니다.

# %%
from keras.layers import Dense, Input, Conv2D, Conv2DTranspose, Flatten, Reshape, MaxPool2D
from keras.models import Model
from keras.layers import BatchNormalization, Dropout, Activation, concatenate

def conv2d_block(x, channel):
    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x
    
def unet_lab():
    inputs = Input((100, 75, 1))

    c1 = conv2d_block(inputs, 16)
    p1 = MaxPool2D(2)(c1)
    p1 = Dropout(0.1)(p1)

    c2 = conv2d_block(p1, 32)
    p2 = MaxPool2D(2)(c2)
    p2 = Dropout(0.1)(p2)

    c3 = conv2d_block(p2, 64)
    p3 = MaxPool2D(2)(c3)
    p3 = Dropout(0.1)(p3)

    c4 = conv2d_block(p3, 128)
    p4 = MaxPool2D(2)(c4)
    p4 = Dropout(0.1)(p4)

    c5 = conv2d_block(p4, 256)
    
    u6 = Conv2DTranspose(128, 2, 2, padding="valid", output_padding=(0,1))(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(0.1)(u6)
    c6 = conv2d_block(u6, 128)

    u7 = Conv2DTranspose(64, 2, 2, padding="valid", output_padding=(1,0))(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(0.1)(u7)
    c7 = conv2d_block(u7, 64)

    u8 = Conv2DTranspose(32, 2, 2, padding="valid", output_padding=(0,1))(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(0.1)(u8)
    c8 = conv2d_block(u8, 32)

    u9 = Conv2DTranspose(16, 2, 2, padding="valid", output_padding=(0,1))(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(0.1)(u9)
    c9 = conv2d_block(u9, 16)

    outputs = Conv2D(2, 1, activation="sigmoid")(c9)
    model = Model(inputs, outputs)
    return model

# %%
model2 = unet_lab()
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 100, 75, 1)] 0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 100, 75, 16)  160         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 100, 75, 16)  64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 100, 75, 16)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 100, 75, 16)  2320        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 100, 75, 16)  64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 100, 75, 16)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 50, 37, 16)   0           activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 50, 37, 16)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 37, 32)   4640        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 50, 37, 32)   128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 50, 37, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 50, 37, 32)   9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 50, 37, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 50, 37, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 25, 18, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 25, 18, 32)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 25, 18, 64)   18496       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 25, 18, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 25, 18, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 25, 18, 64)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 25, 18, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 25, 18, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 12, 9, 64)    0           activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 12, 9, 64)    0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 12, 9, 128)   73856       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 12, 9, 128)   512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 12, 9, 128)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 12, 9, 128)   147584      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 12, 9, 128)   512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 12, 9, 128)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 6, 4, 128)    0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 6, 4, 128)    0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 6, 4, 256)    295168      dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 6, 4, 256)    1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 6, 4, 256)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 6, 4, 256)    590080      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 6, 4, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 6, 4, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 12, 9, 128)   131200      activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12, 9, 256)   0           conv2d_transpose_4[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 12, 9, 256)   0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 9, 128)   295040      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 12, 9, 128)   512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 9, 128)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 9, 128)   147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 9, 128)   512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 9, 128)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 25, 18, 64)   32832       activation_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 25, 18, 128)  0           conv2d_transpose_5[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 25, 18, 128)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 25, 18, 64)   73792       dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 25, 18, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 25, 18, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 18, 64)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 18, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 25, 18, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 50, 37, 32)   8224        activation_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 50, 37, 64)   0           conv2d_transpose_6[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 50, 37, 64)   0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 50, 37, 32)   18464       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 50, 37, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 50, 37, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 50, 37, 32)   9248        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 50, 37, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 50, 37, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 100, 75, 16)  2064        activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 100, 75, 32)  0           conv2d_transpose_7[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 100, 75, 32)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 100, 75, 16)  4624        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 100, 75, 16)  64          conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 100, 75, 16)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 100, 75, 16)  2320        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 100, 75, 16)  64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 100, 75, 16)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 100, 75, 2)   34          activation_35[0][0]
# ==================================================================================================
# Total params: 1,946,722
# Trainable params: 1,943,778
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0287 - accuracy: 0.6583 - val_loss: 0.0315 - val_accuracy: 0.6320
# Epoch 31/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0286 - accuracy: 0.6543 - val_loss: 0.0321 - val_accuracy: 0.6213
# Epoch 32/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0284 - accuracy: 0.6540 - val_loss: 0.0312 - val_accuracy: 0.6503
# Epoch 33/50
# 54/54 [==============================] - 2s 32ms/step - loss: 0.0278 - accuracy: 0.6578 - val_loss: 0.0310 - val_accuracy: 0.6064
# Epoch 34/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0278 - accuracy: 0.6592 - val_loss: 0.0315 - val_accuracy: 0.6181
# Epoch 35/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0275 - accuracy: 0.6564 - val_loss: 0.0310 - val_accuracy: 0.6292
# Epoch 36/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0271 - accuracy: 0.6580 - val_loss: 0.0309 - val_accuracy: 0.6569
# Epoch 37/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0269 - accuracy: 0.6581 - val_loss: 0.0318 - val_accuracy: 0.6477
# Epoch 38/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0269 - accuracy: 0.6643 - val_loss: 0.0315 - val_accuracy: 0.6013
# Epoch 39/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0265 - accuracy: 0.6568 - val_loss: 0.0306 - val_accuracy: 0.6534
# Epoch 40/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0264 - accuracy: 0.6603 - val_loss: 0.0305 - val_accuracy: 0.6212
# Epoch 41/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0261 - accuracy: 0.6625 - val_loss: 0.0314 - val_accuracy: 0.6528
# Epoch 42/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0258 - accuracy: 0.6664 - val_loss: 0.0306 - val_accuracy: 0.6362
# Epoch 43/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0258 - accuracy: 0.6621 - val_loss: 0.0317 - val_accuracy: 0.6545
# Epoch 44/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0255 - accuracy: 0.6693 - val_loss: 0.0312 - val_accuracy: 0.6555
# Epoch 45/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0255 - accuracy: 0.6653 - val_loss: 0.0316 - val_accuracy: 0.5973
# Epoch 46/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0253 - accuracy: 0.6704 - val_loss: 0.0313 - val_accuracy: 0.6401
# Epoch 47/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0251 - accuracy: 0.6693 - val_loss: 0.0306 - val_accuracy: 0.6152
# Epoch 48/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0249 - accuracy: 0.6743 - val_loss: 0.0306 - val_accuracy: 0.6569
# Epoch 49/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0247 - accuracy: 0.6743 - val_loss: 0.0315 - val_accuracy: 0.6521
# Epoch 50/50
# 54/54 [==============================] - 2s 31ms/step - loss: 0.0248 - accuracy: 0.6746 - val_loss: 0.0308 - val_accuracy: 0.6308

# %%
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
plt.plot(hist.history['accuracy'], label='accuracy')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_accuracy'], label='val_accuracy')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend(loc='upper left')
plt.show()

# %%
res = model2.predict(test_lab_images[1:2][...,0:1])

# %%
def l2rgb(l):
    pred_ab = model2.predict(np.expand_dims(l, 0))
    pred_img = np.zeros((100, 75, 3))

    pred_img[:,:,0] = l.reshape((100,75))
    pred_img[:,:,1:] = pred_ab[0]
    
    pred_lab = (pred_img * [100, 255, 255]) - [0, 128, 128]
    rgb_img = color.lab2rgb(pred_lab)
    return rgb_img


plt.imshow(  l2rgb(test_lab_images[1][...,0]) )

# %%
five = np.array( [ l2rgb(img) for img in test_lab_images[:5][...,0] ] )
plt.imshow(np.concatenate([five, test_images[:5]], axis=1).transpose((1,0,2,3)).reshape((200, -1,3)))

# %%
five1 = model.predict(test_gray_images[:5])
five2 = np.array( [ l2rgb(img) for img in test_lab_images[:5][...,0] ] )
plt.imshow(np.concatenate([five1, five2, test_images[:5]], axis=1).transpose((1,0,2,3)).reshape((300, -1,3)))

# %%
loss, acc = model2.evaluate(test_lab_images[...,0], test_lab_images[...,1:], verbose=1)
print(loss, acc)
# Out:
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0308 - accuracy: 0.6308
# 0.030771780759096146 0.6307604312896729
